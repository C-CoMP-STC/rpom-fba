# %%
# Necessary imports
from collections import Counter
import numpy as np
import matplotlib.pyplot as plt
import cobra

# Load model
model = cobra.io.read_sbml_model("../base_model/Rpom_06.xml")
# Out:
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.000e+00  ratio =  1.000e+00
# Problem data seem to be well scaled

# %% [markdown]
# > ### From Matteo:
# >
# > 1) The different models vary in their biomass composition, with the number corresponding to the growth rate across different nutrient sources according to out lab's measurements. For example, Rpom_055 has the biomass extrapolated at a growth rate 0.55/h.
# > 2) I really don't have much to add compared to what I told Arion above - it is mostly to make sure that the pathways are thermodynamically consistent and that the atp/nadh, as well as the individual biomass components are produced in the expected pathways.
# > 3) In addition, there are a few genes to be added to the model (I have added three reactions compared to what Arion did: PDH, PHB-SYNTHESIS, PHB-DEGRADATION). Here are the uniprot IDs of the corresponding proteins:
# >  - Pyruvate dehydrogenase (PDH):
# >     - Q5LR87
# >     - Q5LR88
# >     - Q5LR89
# >     - Q5LKR2
# >   - PHB synthesis (including phasin)
# >     - Q5LTW8
# >     - Q5LTW7
# >   - PHB degradation
# >     - Q5LTW9
# >
# > The problem is that the model was made using a previous Biocyc genome, with different gene names. I don't know whether this older annotation is still available. So, it would be necessary to update the gene IDs to make sure that all genes are properly annotated.

# %% [markdown]
# # Model output

# %%
model.objective.expression
# Out:
# 1.0*EX_glc - 1.0*EX_glc_reverse_8e37d

# %%
model.optimize()
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 EX_glc = -17.21663004483036</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>CA+2[e]</td>
#       <td>EX_ca2</td>
#       <td>0.00203</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>CL-[e]</td>
#       <td>EX_cl</td>
#       <td>0.00203</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>CO+2[e]</td>
#       <td>EX_cobalt2</td>
#       <td>0.001353</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>CU+2[e]</td>
#       <td>EX_cu2</td>
#       <td>0.001353</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>FE+2[e]</td>
#       <td>EX_fe2</td>
#       <td>0.003143</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>FE+3[e]</td>
#       <td>EX_fe3</td>
#       <td>0.003045</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Glucose[e]</td>
#       <td>EX_glc</td>
#       <td>17.22</td>
#       <td>6</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>K+[e]</td>
#       <td>EX_k</td>
#       <td>0.07613</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>MG+2[e]</td>
#       <td>EX_mg2</td>
#       <td>0.003384</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>MN+2[e]</td>
#       <td>EX_mn2</td>
#       <td>0.001353</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>CPD-3[e]</td>
#       <td>EX_mobd</td>
#       <td>0.001353</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>AMMONIUM[e]</td>
#       <td>EX_nh4</td>
#       <td>4.208</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>OXYGEN-MOLECULE[e]</td>
#       <td>EX_o2</td>
#       <td>75.95</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>Pi[e]</td>
#       <td>EX_pi</td>
#       <td>0.4099</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>SULFATE[e]</td>
#       <td>EX_so4</td>
#       <td>0.06893</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>THIAMINE[e]</td>
#       <td>EX_thm</td>
#       <td>9.737E-05</td>
#       <td>12</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>ZN+2[e]</td>
#       <td>EX_zn2</td>
#       <td>0.001353</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>CARBON-DIOXIDE[e]</td>
#       <td>EX_co2</td>
#       <td>-77.79</td>
#       <td>1</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>PROTON[e]</td>
#       <td>EX_h</td>
#       <td>-3.811</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>WATER[e]</td>
#       <td>EX_h2o</td>
#       <td>-90.4</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.metabolites.query(lambda n: n == "ATP", attribute="name")[0].summary()
# Out:
# <h3>ATP[c]</h3><p>C10H12N5O13P3</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.40%</td>
#       <td>0.3601</td>
#       <td>ADENYL-KIN-RXN</td>
#       <td>AMP[c] + ATP[c] &lt;=&gt; 2.0 ADP[c]</td>
#     </tr>
#     <tr>
#       <td>0.72%</td>
#       <td>0.64</td>
#       <td>MALATE--COA-LIGASE-RXN</td>
#       <td>ATP[c] + CO-A[c] + MAL[c] &lt;=&gt; ADP[c] + CPD-208[c] + Pi[c]</td>
#     </tr>
#     <tr>
#       <td>34.31%</td>
#       <td>30.67</td>
#       <td>PEPDEPHOS-RXN</td>
#       <td>ADP[c] + PHOSPHO-ENOL-PYRUVATE[c] + PROTON[c] --&gt; ATP[c] + PYRUVATE[c]</td>
#     </tr>
#     <tr>
#       <td>37.12%</td>
#       <td>33.18</td>
#       <td>PHOSGLYPHOS-RXN</td>
#       <td>ATP[c] + G3P[c] &lt;=&gt; ADP[c] + DPG[c]</td>
#     </tr>
#     <tr>
#       <td>1.46%</td>
#       <td>1.306</td>
#       <td>PYRUVATEORTHOPHOSPHATE-DIKINASE-RXN</td>
#       <td>ATP[c] + PYRUVATE[c] + Pi[c] &lt;=&gt; AMP[c] + PHOSPHO-ENOL-PYRUVATE[c] + PPI[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>25.99%</td>
#       <td>23.23</td>
#       <td>SUCCCOASYN-RXN</td>
#       <td>ATP[c] + CO-A[c] + SUC[c] &lt;=&gt; ADP[c] + Pi[c] + SUC-COA[c]</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.001044</td>
#       <td>2.7.1.148-RXN</td>
#       <td>4-CYTIDINE-5-DIPHOSPHO-2-C[c] + ATP[c] --&gt; 2-PHOSPHO-4-CYTIDINE-5-DIPHOSPHO-2-C-MET[c] + ADP[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.02%</td>
#       <td>-0.02123</td>
#       <td>3.6.3.1-RXN</td>
#       <td>ATP[c] + CPD-17086[c] + WATER[c] --&gt; ADP[c] + CPD-17086[p] + PROTON[c] + Pi[c]</td>
#     </tr>
#     <tr>
#       <td>0.02%</td>
#       <td>-0.01802</td>
#       <td>3.6.3.1-RXN-2</td>
#       <td>ATP[c] + CPD-12819[c] + WATER[c] --&gt; ADP[c] + CPD-12819[p] + PROTON[c] + Pi[c]</td>
#     </tr>
#     <tr>
#       <td>18.58%</td>
#       <td>-16.61</td>
#       <td>6PFRUCTPHOS-RXN</td>
#       <td>ATP[c] + FRUCTOSE-6P[c] --&gt; ADP[c] + FRUCTOSE-16-DIPHOSPHATE[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.07%</td>
#       <td>-0.06529</td>
#       <td>AACPS4</td>
#       <td>ACP[c] + ATP[c] + hdcea[c] &lt;=&gt; AMP[c] + PPI[c] + hdeACP[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-9.737E-05</td>
#       <td>ABC-32-RXN</td>
#       <td>ATP[c] + THIAMINE[p] + WATER[c] --&gt; ADP[c] + PROTON[c] + Pi[c] + THIAMINE[c]</td>
#     </tr>
#     <tr>
#       <td>0.04%</td>
#       <td>-0.03503</td>
#       <td>ACETATE--COA-LIGASE-RXN</td>
#       <td>ACET[c] + ATP[c] + CO-A[c] --&gt; ACETYL-COA[c] + AMP[c] + PPI[c]</td>
#     </tr>
#     <tr>
#       <td>1.17%</td>
#       <td>-1.048</td>
#       <td>ACETYL-COA-CARBOXYLTRANSFER-RXN</td>
#       <td>ACETYL-COA[c] + ATP[c] + HCO3[c] --&gt; ADP[c] + MALONYL-COA[c] + PROTON[c] + Pi[c]</td>
#     </tr>
#     <tr>
#       <td>0.27%</td>
#       <td>-0.2419</td>
#       <td>ACETYLGLUTKIN-RXN</td>
#       <td>ACETYL-GLU[c] + ATP[c] --&gt; ADP[c] + N-ACETYL-GLUTAMYL-P[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0002921</td>
#       <td>ADENOSINE-KINASE-RXN</td>
#       <td>ADENOSINE[c] + ATP[c] --&gt; ADP[c] + AMP[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.08%</td>
#       <td>-0.06724</td>
#       <td>ADENYLYLSULFKIN-RXN</td>
#       <td>APS[c] + ATP[c] --&gt; ADP[c] + PAPS[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.21%</td>
#       <td>-0.1853</td>
#       <td>AIRS-RXN</td>
#       <td>5-PHOSPHORIBOSYL-N-FORMYLGLYCINEAMIDINE[c] + ATP[c] --&gt; 5-PHOSPHORIBOSYL-5-AMINOIMIDAZOLE[c] + ADP[c] + PROTON[c] + Pi[c]</td>
#     </tr>
#     <tr>
#       <td>0.09%</td>
#       <td>-0.07715</td>
#       <td>ARGSUCCINSYN-RXN</td>
#       <td>ATP[c] + L-ASPARTATE[c] + L-CITRULLINE[c] --&gt; AMP[c] + L-ARGININO-SUCCINATE[c] + PPI[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.09%</td>
#       <td>-0.08111</td>
#       <td>ASNSYNB-RXN</td>
#       <td>ATP[c] + GLN[c] + L-ASPARTATE[c] + WATER[c] --&gt; AMP[c] + ASN[c] + GLT[c] + PPI[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.43%</td>
#       <td>-0.38</td>
#       <td>ASPARTATEKIN-RXN</td>
#       <td>ATP[c] + L-ASPARTATE[c] --&gt; ADP[c] + L-BETA-ASPARTYL-P[c]</td>
#     </tr>
#     <tr>
#       <td>35.80%</td>
#       <td>-32</td>
#       <td>ATPM</td>
#       <td>ATP[c] + WATER[c] --&gt; ADP[c] + PROTON[c] + Pi[c]</td>
#     </tr>
#     <tr>
#       <td>0.04%</td>
#       <td>-0.03937</td>
#       <td>ATPPHOSPHORIBOSYLTRANS-RXN</td>
#       <td>ATP[c] + PROTON[c] + PRPP[c] --&gt; PHOSPHORIBOSYL-ATP[c] + PPI[c]</td>
#     </tr>
#     <tr>
#       <td>1.06%</td>
#       <td>-0.9514</td>
#       <td>ATPSYN-RXN</td>
#       <td>ATP[c] + 3.0 PROTON[c] + WATER[c] &lt;=&gt; ADP[c] + 4.0 PROTON[p] + Pi[c]</td>
#     </tr>
#     <tr>
#       <td>0.08%</td>
#       <td>-0.07473</td>
#       <td>BiomassRxn</td>
#       <td>0.000162290114245086 10-FORMYL-DIHYDROFOLATE-GLU-N[c] + 0.000162290114245086 5-METHYL-THF-GLU-N[c] + 0.00845926363395877 AMMONIUM[c] + 0.128580538479686 ARG[c] + 0.135191382524646 ASN[c] + 0.124548643234806 ATP[c] + 0.00338370545358347 CA+2[c] + 0.000162290114245086 CHORISMATE[c] + 0.00338370545358347 CL-[c] + 0.00225580363572238 CO+2[c] + 0.000418708494752947 CO-A[c] + 0.0161318380372958 CPD-12819[c] + 0.0300309653237938 CPD-12819[p] + 0.0190283276599524 CPD-17086[c] + 0.0353814253212012 CPD-17086[p] + 0.00225580363572238 CPD-3[c] + 0.000162290114245086 CPD-9956[c] + 0.0100661803738848 CPD0-2278[p] + 0.09851309854217 CTP[c] + 0.00225580363572238 CU+2[c] + 0.0297941815710398 CYS[c] + 0.0230896063265699 DATP[c] + 0.0181613886555637 DCTP[c] + 0.0181613886555637 DGTP[c] + 0.0230896063265699 DTTP[c] + 0.000162290114245086 ENTEROBACTIN[c] + 0.000162290114245086 FAD[c] + 0.0050755581803753 FE+2[c] + 0.0050755581803753 FE+3[c] + 0.309353313478458 GLN[c] + 0.371352668084298 GLT[c] + 0.20720722480387 GLY[c] + 0.139737092941916 GTP[c] + 0.0656148963146431 HIS[c] + 0.194768399824541 ILE[c] + 0.126888954509381 K+[c] + 0.0140854487028574 KDO2-LIPID-IVA[p] + 0.254513713783477 L-ALPHA-ALANINE[c] + 0.174421522844066 L-ASPARTATE[c] + 0.311242924695585 LEU[c] + 0.164764320173129 LYS[c] + 0.000162290114245086 METHYLENE-THF-GLU-N[c] + 0.0816843907923462 MET[c] + 0.00563950908930585 MG+2[c] + 0.00225580363572238 MN+2[c] + 0.000324580228490899 NADP[c] + 0.00133077893681145 NAD[c] + 3.64249055755264 PHB-MONOMER[c] + 0.129011680482618 PHE[c] + 0.000162290114245086 PROTOHEME[c] + 0.116446160265587 PRO[c] + 0.000162290114245086 PYRIDOXAL_PHOSPHATE[c] + 0.00281975454465292 Pi[c] + 0.000162290114245086 RIBOFLAVIN[c] + 0.000162290114245086 S-ADENOSYLMETHIONINE[c] + 0.216943848370085 SER[c] + 0.00281975454465292 SULFATE[c] + 0.000162290114245086 THF-GLU-N[c] + 0.000162290114245086 THIAMINE-PYROPHOSPHATE[c] + 0.171806306221017 THR[c] + 0.0374885535444169 TRP[c] + 0.093775276611411 TYR[c] + 4.02231901548373e-05 UNDECAPRENYL-DIPHOSPHATE[c] + 0.100581009535157 UTP[c] + 0.21937374957082 VAL[c] + 0.00225580363572238 ZN+2[c] --&gt; 0.545881834218316 PPI[c] + 3.07118332867536 WATER[c]</td>
#     </tr>
#     <tr>
#       <td>0.25%</td>
#       <td>-0.2214</td>
#       <td>CARBAMATE-KINASE-RXN</td>
#       <td>AMMONIUM[c] + ATP[c] + HCO3[c] &lt;=&gt; ADP[c] + CARBAMOYL-P[c] + PROTON[c] + WATER[c]</td>
#     </tr>
#     <tr>
#       <td>0.08%</td>
#       <td>-0.06764</td>
#       <td>CDPKIN-RXN</td>
#       <td>ATP[c] + CDP[c] --&gt; ADP[c] + CTP[c]</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.01208</td>
#       <td>DALADALALIG-RXN</td>
#       <td>ATP[c] + 2.0 D-ALANINE[c] --&gt; ADP[c] + D-ALA-D-ALA[c] + PROTON[c] + Pi[c]</td>
#     </tr>
#     <tr>
#       <td>0.01%</td>
#       <td>-0.0109</td>
#       <td>DCDPKIN-RXN</td>
#       <td>ATP[c] + DCDP[c] --&gt; ADP[c] + DCTP[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0002512</td>
#       <td>DEPHOSPHOCOAKIN-RXN</td>

# %%
model.metabolites.query(lambda n: n == "NADH", attribute="name")[0].summary()
# Out:
# <h3>NADH[c]</h3><p>C21H27N7O14P2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.00%</td>
#       <td>0.0009737</td>
#       <td>1.2.1.2-RXN</td>
#       <td>FORMATE[c] + NAD[c] --&gt; CARBON-DIOXIDE[c] + NADH[c]</td>
#     </tr>
#     <tr>
#       <td>0.46%</td>
#       <td>0.4102</td>
#       <td>1.5.1.15-RXN</td>
#       <td>METHYLENE-THF-GLU-N[c] + NAD[c] --&gt; 5-10-METHENYL-THF-GLU-N[c] + NADH[c]</td>
#     </tr>
#     <tr>
#       <td>25.40%</td>
#       <td>22.75</td>
#       <td>2OXOGLUTARATEDEH-RXN</td>
#       <td>2-KETOGLUTARATE[c] + CO-A[c] + NAD[c] --&gt; CARBON-DIOXIDE[c] + NADH[c] + SUC-COA[c]</td>
#     </tr>
#     <tr>
#       <td>0.18%</td>
#       <td>0.1648</td>
#       <td>AMINOBUTDEHYDROG-RXN</td>
#       <td>4-AMINO-BUTYRALDEHYDE[c] + NAD[c] + WATER[c] --&gt; 4-AMINO-BUTYRATE[c] + NADH[c] + 2.0 PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>0.0002921</td>
#       <td>DHBDEHYD-RXN</td>
#       <td>DIHYDRO-DIOH-BENZOATE[c] + NAD[c] --&gt; 2-3-DIHYDROXYBENZOATE[c] + NADH[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>9.737E-05</td>
#       <td>ERYTH4PDEHYDROG-RXN</td>
#       <td>ERYTHROSE-4P[c] + NAD[c] + WATER[c] --&gt; ERYTHRONATE-4P[c] + NADH[c] + 2.0 PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>9.737E-05</td>
#       <td>ERYTHRON4PDEHYDROG-RXN</td>
#       <td>ERYTHRONATE-4P[c] + NAD[c] --&gt; 3OH-4P-OH-ALPHA-KETOBUTYRATE[c] + NADH[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>37.05%</td>
#       <td>33.18</td>
#       <td>GAPOXNPHOSPHN-RXN</td>
#       <td>GAP[c] + NAD[c] + Pi[c] &lt;=&gt; DPG[c] + NADH[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.09%</td>
#       <td>0.0817</td>
#       <td>GCVMULTI-RXN</td>
#       <td>GLY[c] + NAD[c] + THF-GLU-N[c] --&gt; AMMONIUM[c] + CARBON-DIOXIDE[c] + METHYLENE-THF-GLU-N[c] + NADH[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>0.0003895</td>
#       <td>GLYCOLALD-DEHYDROG-RXN</td>
#       <td>GLYCOLALDEHYDE[c] + NAD[c] + WATER[c] --&gt; GLYCOLATE[c] + NADH[c] + 2.0 PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>0.0003895</td>
#       <td>GLYCOLATEDEHYDRO-RXN</td>
#       <td>GLYOX[c] + NADH[c] + PROTON[c] &lt;-- GLYCOLATE[c] + NAD[c]</td>
#     </tr>
#     <tr>
#       <td>0.11%</td>
#       <td>0.09532</td>
#       <td>IMP-DEHYDROG-RXN</td>
#       <td>IMP[c] + NAD[c] + WATER[c] &lt;=&gt; NADH[c] + PROTON[c] + XANTHOSINE-5-PHOSPHATE[c]</td>
#     </tr>
#     <tr>
#       <td>0.71%</td>
#       <td>0.64</td>
#       <td>MALATE-DEH-RXN</td>
#       <td>MAL[c] + NAD[c] &lt;=&gt; NADH[c] + OXALACETIC_ACID[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>34.82%</td>
#       <td>31.19</td>
#       <td>PDH</td>
#       <td>CO-A[c] + NAD[c] + PYRUVATE[c] --&gt; ACETYL-COA[c] + CARBON-DIOXIDE[c] + NADH[c]</td>
#     </tr>
#     <tr>
#       <td>0.70%</td>
#       <td>0.6236</td>
#       <td>PGLYCDEHYDROG-RXN</td>
#       <td>G3P[c] + NAD[c] &lt;=&gt; 3-P-HYDROXYPYRUVATE[c] + NADH[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.21%</td>
#       <td>0.1867</td>
#       <td>RXN-13158</td>
#       <td>2-D-THREO-HYDROXY-3-CARBOXY-ISOCAPROATE[c] + NAD[c] --&gt; 2K-4CH3-PENTANOATE[c] + CARBON-DIOXIDE[c] + NADH[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>9.737E-05</td>
#       <td>RXN-13179</td>
#       <td>4-PHOSPHONOOXY-THREONINE[c] + NAD[c] --&gt; 1-AMINO-PROPAN-2-ONE-3-PHOSPHATE[c] + CARBON-DIOXIDE[c] + NADH[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>9.737E-05</td>
#       <td>RXN-13909</td>
#       <td>FORMYL-THF-GLU-N[c] + NAD[c] &lt;=&gt; 10-FORMYL-DIHYDROFOLATE-GLU-N[c] + NADH[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.09%</td>
#       <td>0.07874</td>
#       <td>RXN-8001</td>
#       <td>HISTIDINOL[c] + 2.0 NAD[c] + WATER[c] --&gt; HIS[c] + 2.0 NADH[c] + 3.0 PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.18%</td>
#       <td>0.1648</td>
#       <td>SUCCINATE-SEMIALDEHYDE-DEHYDROGENASE-RXN</td>
#       <td>NAD[c] + SUCC-S-ALD[c] + WATER[c] --&gt; NADH[c] + 2.0 PROTON[c] + SUC[c]</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.06%</td>
#       <td>-0.0495</td>
#       <td>1.5.1.20-RXN</td>
#       <td>METHYLENE-THF-GLU-N[c] + NADH[c] + PROTON[c] --&gt; 5-METHYL-THF-GLU-N[c] + NAD[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-0.0002512</td>
#       <td>ACETALD-DEHYDROG-RXN</td>
#       <td>ACETALD[c] + CO-A[c] + NAD[c] &lt;=&gt; ACETYL-COA[c] + NADH[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>23.08%</td>
#       <td>-20.67</td>
#       <td>ALCOHOL-DEHYDROG-RXN</td>
#       <td>ETOH[c] + NAD[c] &lt;=&gt; ACETALD[c] + NADH[c] + PROTON[c]</td>
#     </tr>
#     <tr>
#       <td>0.00%</td>
#       <td>-9.737E-05</td>
#       <td>OCTAPRENYL-METHYL-METHOXY-BENZOQ-OH-RXN</td>
#       <td>NADH[c] + OCTAPRENYL-METHYL-METHOXY-BENZQ[c] + OXYGEN-MOLECULE[c] + PROTON[c] --&gt; NAD[c] + OCTAPRENYL-METHYL-OH-METHOXY-BENZQ[c] + WATER[c]</td>
#     </tr>
#     <tr>
#       <td>76.80%</td>
#       <td>-68.78</td>
#       <td>PYRROLINECARBREDUCT-RXN-PRO/NAD//L-DELTA1-PYRROLINE_5-CARBOXYLATE/NADH/PROTON.54.</td>
#       <td>L-DELTA1-PYRROLINE_5-CARBOXYLATE[c] + NADH[c] + 2.0 PROTON[c] --&gt; NAD[c] + PRO[c]</td>
#     </tr>
#     <tr>
#       <td>0.06%</td>
#       <td>-0.05627</td>
#       <td>RXN-7909</td>
#       <td>CPD-14202[c] + NADH[c] + PROTON[c] --&gt; CPD-14053[c] + NAD[c]</td>
#     </tr>
#   </tbody>
# </table>
